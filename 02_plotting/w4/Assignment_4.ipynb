# %% [markdown]
# # Assignment 4
#
# Before working on this assignment please read these instructions fully. In the submission area, you will notice that you can click the link to **Preview the Grading** for each step of the assignment. This is the criteria that will be used for peer grading. Please familiarize yourself with the criteria before beginning the assignment.
#
# This assignment requires that you to find **at least** two datasets on the web which are related, and that you visualize these datasets to answer a question with the broad topic of **economic activity or measures** (see below) for the region of **Bogotá, Bogota D.C., Colombia**, or **Colombia** more broadly.
#
# You can merge these datasets with data from different regions if you like! For instance, you might want to compare **Bogotá, Bogota D.C., Colombia** to Ann Arbor, USA. In that case at least one source file must be about **Bogotá, Bogota D.C., Colombia**.
#
# You are welcome to choose datasets at your discretion, but keep in mind **they will be shared with your peers**, so choose appropriate datasets. Sensitive, confidential, illicit, and proprietary materials are not good choices for datasets for this assignment. You are welcome to upload datasets of your own as well, and link to them using a third party repository such as github, bitbucket, pastebin, etc. Please be aware of the Coursera terms of service with respect to intellectual property.
#
# Also, you are welcome to preserve data in its original language, but for the purposes of grading you should provide english translations. You are welcome to provide multiple visuals in different languages if you would like!
#
# As this assignment is for the whole course, you must incorporate principles discussed in the first week, such as having as high data-ink ratio (Tufte) and aligning with Cairo’s principles of truth, beauty, function, and insight.
#
# Here are the assignment instructions:
#
#  * State the region and the domain category that your data sets are about (e.g., **Bogotá, Bogota D.C., Colombia** and **economic activity or measures**).
#  * You must state a question about the domain category and region that you identified as being interesting.
#  * You must provide at least two links to available datasets. These could be links to files such as CSV or Excel files, or links to websites which might have data in tabular form, such as Wikipedia pages.
#  * You must upload an image which addresses the research question you stated. In addition to addressing the question, this visual should follow Cairo's principles of truthfulness, functionality, beauty, and insightfulness.
#  * You must contribute a short (1-2 paragraph) written justification of how your visualization addresses your stated research question.
#
# What do we mean by **economic activity or measures**?  For this category you might look at the inputs or outputs to the given economy, or major changes in the economy compared to other regions.
#
# ## Tips
# * Wikipedia is an excellent source of data, and I strongly encourage you to explore it for new data sources.
# * Many governments run open data initiatives at the city, region, and country levels, and these are wonderful resources for localized data sources.
# * Several international agencies, such as the [United Nations](http://data.un.org/), the [World Bank](http://data.worldbank.org/), the [Global Open Data Index](http://index.okfn.org/place/) are other great places to look for data.
# * This assignment requires you to convert and clean datafiles. Check out the discussion forums for tips on how to do this from various sources, and share your successes with your fellow students!
#
# ## Example
# Looking for an example? Here's what our course assistant put together for the **Ann Arbor, MI, USA** area using **sports and athletics** as the topic. [Example Solution File](./readonly/Assignment4_example.pdf)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
emission2014 = pd.read_csv('../data/emisiones_2014.csv')

# %%
emission2014.columns
# Out:
# Index(['Autoridad Ambiental', 'Estación', 'Latitud', 'Longitud', 'Ubicación ',
#        'Departamento', 'Municipio', 'Tipo de Estación', 'Unidades', 'Variable',
#        'Tiempo Promedio', 'Promedio', 'Número de excedencias',
#        'Representatividad Temporal', 'Porcentaje de excedencias', 'Mediana',
#        'Percentil 98', 'Máximo', 'Mínimo', 'Días con excedencias'],
#       dtype='object')

# %%
PIB = pd.read_csv('../data/PIB_2010_2016.csv', nrows=34)

# %%
air_quality = pd.read_csv('../data/calidad_aire_2011_2018.csv', nrows=34)
air_quality['Fecha'] = pd.to_datetime(air_quality['Fecha'])

# %%
air_quality.columns
# Out:
# Index(['Fecha', 'Autoridad Ambiental', 'Nombre de la estación', 'Tecnología',
#        'Latitud', 'Longitud', 'Código del departamento', 'Departamento',
#        'Código del municipio', 'Nombre del municipio', 'Tipo de estación',
#        'Tiempo de exposición', 'Variable', 'Unidades', 'Concentración',
#        'Nueva columna georreferenciada'],
#       dtype='object')

# %%
air_quality.head()
# Out:
#                        Fecha Autoridad Ambiental Nombre de la estación  \
# 0  09/04/2011 12:00:00 a. m.                AMVA   BAR-Hosp. S.V. Paul
# 1  13/04/2011 12:00:00 a. m.                AMVA   BAR-Hosp. S.V. Paul
# 2  15/04/2011 12:00:00 a. m.                AMVA   BAR-Hosp. S.V. Paul
# 3  18/04/2011 12:00:00 a. m.                AMVA   BAR-Hosp. S.V. Paul
# 4  20/04/2011 12:00:00 a. m.                AMVA   BAR-Hosp. S.V. Paul
#
#   Tecnología  Latitud   Longitud  Código del departamento Departamento  \
# 0     Manual    6.436 -75.333431                        5    ANTIOQUIA
# 1     Manual    6.436 -75.333431                        5    ANTIOQUIA
# 2     Manual    6.436 -75.333431                        5    ANTIOQUIA
# 3     Manual    6.436 -75.333431                        5    ANTIOQUIA
# 4     Manual    6.436 -75.333431                        5    ANTIOQUIA
#
#    Código del municipio Nombre del municipio Tipo de estación  \
# 0                  5079              BARBOSA             Fija
# 1                  5079              BARBOSA             Fija
# 2                  5079              BARBOSA             Fija
# 3                  5079              BARBOSA             Fija
# 4                  5079              BARBOSA             Fija
#
#    Tiempo de exposición Variable Unidades  Concentración  \
# 0                    24     PM10    µg/m3          55.57
# 1                    24     PM10    µg/m3          30.81
# 2                    24     PM10    µg/m3          21.01
# 3                    24     PM10    µg/m3          30.73
# 4                    24     PM10    µg/m3          24.72
#
#   Nueva columna georreferenciada
# 0            (6.436, -75.333431)
# 1            (6.436, -75.333431)
# 2            (6.436, -75.333431)
# 3            (6.436, -75.333431)
# 4            (6.436, -75.333431)

# %%
air_quality['Fecha'] = pd.to_datetime(air_quality['Fecha'])

# %%
air_quality
# Out:
#         Fecha Autoridad Ambiental Nombre de la estación Tecnología  Latitud  \
# 0  2011-09-04                AMVA   BAR-Hosp. S.V. Paul     Manual    6.436
# 1  2011-04-13                AMVA   BAR-Hosp. S.V. Paul     Manual    6.436
# 2  2011-04-15                AMVA   BAR-Hosp. S.V. Paul     Manual    6.436
# 3  2011-04-18                AMVA   BAR-Hosp. S.V. Paul     Manual    6.436
# 4  2011-04-20                AMVA   BAR-Hosp. S.V. Paul     Manual    6.436
# 5  2011-04-24                AMVA   BAR-Hosp. S.V. Paul     Manual    6.436
# 6  2011-04-27                AMVA   BAR-Hosp. S.V. Paul     Manual    6.436
# 7  2011-04-30                AMVA   BAR-Hosp. S.V. Paul     Manual    6.436
# 8  2011-04-05                AMVA   BAR-Hosp. S.V. Paul     Manual    6.436
# 9  2011-06-05                AMVA   BAR-Hosp. S.V. Paul     Manual    6.436
# 10 2011-09-05                AMVA   BAR-Hosp. S.V. Paul     Manual    6.436
# 11 2011-12-05                AMVA   BAR-Hosp. S.V. Paul     Manual    6.436
# 12 2011-05-15                AMVA   BAR-Hosp. S.V. Paul     Manual    6.436
# 13 2011-05-18                AMVA   BAR-Hosp. S.V. Paul     Manual    6.436
# 14 2011-05-21                AMVA   BAR-Hosp. S.V. Paul     Manual    6.436
# 15 2011-05-24                AMVA   BAR-Hosp. S.V. Paul     Manual    6.436
# 16 2011-05-27                AMVA   BAR-Hosp. S.V. Paul     Manual    6.436
#    Nombre del municipio Tipo de estación  Tiempo de exposición Variable  \
# 0               BARBOSA             Fija                    24     PM10
# 1               BARBOSA             Fija                    24     PM10
# 2               BARBOSA             Fija                    24     PM10
# 3               BARBOSA             Fija                    24     PM10
# 4               BARBOSA             Fija                    24     PM10
# 5               BARBOSA             Fija                    24     PM10
# 6               BARBOSA             Fija                    24     PM10
# 7               BARBOSA             Fija                    24     PM10
# 8               BARBOSA             Fija                    24     PM10
# 9               BARBOSA             Fija                    24     PM10
# 10              BARBOSA             Fija                    24     PM10
# 11              BARBOSA             Fija                    24     PM10
# 12              BARBOSA             Fija                    24     PM10
# 13              BARBOSA             Fija                    24     PM10
# 14              BARBOSA             Fija                    24     PM10
# 15              BARBOSA             Fija                    24     PM10
# 16              BARBOSA             Fija                    24     PM10
# 17              BARBOSA             Fija                    24     PM10
# 18              BARBOSA             Fija                    24     PM10
# 19              BARBOSA             Fija                    24     PM10
# 20              BARBOSA             Fija                    24     PM10
# 21              BARBOSA             Fija                    24     PM10
# 22              BARBOSA             Fija                    24     PM10
# 23              BARBOSA             Fija                    24     PM10
# 24              BARBOSA             Fija                    24     PM10
# 25              BARBOSA             Fija                    24     PM10
# 26              BARBOSA             Fija                    24     PM10
# 27              BARBOSA             Fija                    24     PM10
# 28              BARBOSA             Fija                    24     PM10
# 29              BARBOSA             Fija                    24     PM10
# 30              BARBOSA             Fija                    24     PM10
# 31              BARBOSA             Fija                    24     PM10
# 32              BARBOSA             Fija                    24     PM10
# 33              BARBOSA             Fija                    24     PM10
#
#    Unidades  Concentración Nueva columna georreferenciada
# 0     µg/m3          55.57            (6.436, -75.333431)
# 1     µg/m3          30.81            (6.436, -75.333431)
# 2     µg/m3          21.01            (6.436, -75.333431)
# 3     µg/m3          30.73            (6.436, -75.333431)
# 4     µg/m3          24.72            (6.436, -75.333431)
# 5     µg/m3          22.56            (6.436, -75.333431)
# 6     µg/m3          25.39            (6.436, -75.333431)
# 7     µg/m3          37.54            (6.436, -75.333431)
# 8     µg/m3          34.13            (6.436, -75.333431)
# 9     µg/m3          34.08            (6.436, -75.333431)
# 10    µg/m3          31.77            (6.436, -75.333431)
# 11    µg/m3          42.09            (6.436, -75.333431)
# 12    µg/m3          25.03            (6.436, -75.333431)
# 13    µg/m3          34.72            (6.436, -75.333431)
# 14    µg/m3          28.93            (6.436, -75.333431)
# 15    µg/m3          17.78            (6.436, -75.333431)
# 16    µg/m3          27.65            (6.436, -75.333431)
# 17    µg/m3          84.80            (6.436, -75.333431)
# 18    µg/m3          43.80            (6.436, -75.333431)
# 19    µg/m3          86.92            (6.436, -75.333431)
# 20    µg/m3           9.70            (6.436, -75.333431)
# 21    µg/m3          39.14            (6.436, -75.333431)
# 22    µg/m3          32.30            (6.436, -75.333431)
# 23    µg/m3          24.25            (6.436, -75.333431)
# 24    µg/m3          24.59            (6.436, -75.333431)
# 25    µg/m3          19.74            (6.436, -75.333431)
# 26    µg/m3          27.94            (6.436, -75.333431)
# 27    µg/m3          35.04            (6.436, -75.333431)
# 28    µg/m3          20.38            (6.436, -75.333431)
# 29    µg/m3          42.85            (6.436, -75.333431)
# 30    µg/m3          30.11            (6.436, -75.333431)
# 31    µg/m3          25.00            (6.436, -75.333431)
# 32    µg/m3          21.17            (6.436, -75.333431)
# 33    µg/m3          20.79            (6.436, -75.333431)
